# %%
import pandas as pd
import pandas as pd
import re
import openpyxl
import datetime
import sqlite3
import pyarrow as pa
import pyarrow.parquet as pq
from pathlib import Path
import decimal
TOPDIR = r'/home/pp/program/jupyter/Brezno - Klima/'
TEMPDIR= TOPDIR + r'temp/'

# Replace 'your_file.parquet' with the path to your Parquet file
df = pd.read_parquet(TEMPDIR + 'teplotyx.parquet'   )

print(df.head())
# Out:
#             Stanica Teplota  Smer Rýchlosť Nárazy    Tlak Oblačnosť Počasie  \
# 84          Trenčín    23.4     Z        3   None  1014.8      None    None
# 65          Rožňava    24.5    JV        1   None  1013.2      None    None
# 64          Roztoky    21.6  None        -   None    None      None    None
# 63  Rimavská Sobota    25.6     Z        1   None    None      None    None
# 62           Revúca    22.8     J        2   None  1013.5      None    None
#
#     Graf            datetime
# 84   NaN 2025-07-30 14:00:00
# 65   NaN 2025-07-30 14:00:00
# 64   NaN 2025-07-30 14:00:00
# 63   NaN 2025-07-30 14:00:00
# 62   NaN 2025-07-30 14:00:00

# %%
df.index = df['Stanica']
brez = df.loc[['Roztoky'],:]

# %%
brez
# Out:
#          Stanica Teplota  Smer Rýchlosť Nárazy  Tlak Oblačnosť Počasie  Graf  \
# Stanica
# Roztoky  Roztoky    21.6  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    21.9  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    22.2  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    21.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    21.8  None        -   None  None      None    None   NaN
# ...          ...     ...   ...      ...    ...   ...       ...     ...   ...
# Roztoky  Roztoky    26.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    24.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    22.8  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    22.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    21.7  None        -   None  None      None    None   NaN
#
#                    datetime
# Stanica
# Roztoky 2025-07-30 14:00:00
# Roztoky 2025-07-30 15:00:00
# Roztoky 2025-07-30 16:00:00
# Roztoky 2025-07-30 17:00:00
# Roztoky 2025-07-30 18:00:00
# ...                     ...
# Roztoky 2025-08-16 19:00:00
# Roztoky 2025-08-16 20:00:00
# Roztoky 2025-08-16 21:00:00
# Roztoky 2025-08-16 22:00:00
# Roztoky 2025-08-16 23:00:00
#
# [418 rows x 10 columns]

# %%
brez
# Out:
#          Stanica Teplota  Smer Rýchlosť Nárazy  Tlak Oblačnosť Počasie  Graf  \
# Stanica
# Roztoky  Roztoky    21.6  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    21.9  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    22.2  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    21.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    21.8  None        -   None  None      None    None   NaN
# ...          ...     ...   ...      ...    ...   ...       ...     ...   ...
# Roztoky  Roztoky    26.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    24.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    22.8  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    22.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky    21.7  None        -   None  None      None    None   NaN
#
#                    datetime
# Stanica
# Roztoky 2025-07-30 14:00:00
# Roztoky 2025-07-30 15:00:00
# Roztoky 2025-07-30 16:00:00
# Roztoky 2025-07-30 17:00:00
# Roztoky 2025-07-30 18:00:00
# ...                     ...
# Roztoky 2025-08-16 19:00:00
# Roztoky 2025-08-16 20:00:00
# Roztoky 2025-08-16 21:00:00
# Roztoky 2025-08-16 22:00:00
# Roztoky 2025-08-16 23:00:00
#
# [418 rows x 10 columns]

# %%
brez.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, Roztoky to Roztoky
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Stanica    418 non-null    object
#  1   Teplota    418 non-null    object
#  2   Smer       0 non-null      object
#  3   Rýchlosť   418 non-null    object
#  4   Nárazy     0 non-null      object
#  5   Tlak       0 non-null      object
#  6   Oblačnosť  0 non-null      object
#  7   Počasie    0 non-null      object
#  8   Graf       0 non-null      float64
#  9   datetime   418 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(1), object(8)
# memory usage: 52.1+ KB

# %%
tf = brez
tf.describe()
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, Roztoky to Roztoky
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Stanica    418 non-null    object
#  1   Teplota    418 non-null    object
#  2   Smer       0 non-null      object
#  3   Rýchlosť   418 non-null    object
#  4   Nárazy     0 non-null      object
#  5   Tlak       0 non-null      object
#  6   Oblačnosť  0 non-null      object
#  7   Počasie    0 non-null      object
#  8   Graf       0 non-null      float64
#  9   datetime   418 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(1), object(8)
# memory usage: 52.1+ KB

# %%
tf.Teplota = tf.Teplota.astype(float)
print(tf.describe())
# Out:
#           Teplota  Graf             datetime
# count  418.000000   0.0                  418
# mean    18.938995   NaN  2025-08-08 06:30:00
# min      8.100000   NaN  2025-07-30 14:00:00
# 25%     15.300000   NaN  2025-08-03 22:15:00
# 50%     18.500000   NaN  2025-08-08 06:30:00
# 75%     22.400000   NaN  2025-08-12 14:45:00
# max     30.400000   NaN  2025-08-16 23:00:00
# std      5.138260   NaN                  NaN

# %%
tf
# Out:
#          Stanica  Teplota  Smer Rýchlosť Nárazy  Tlak Oblačnosť Počasie  Graf  \
# Stanica
# Roztoky  Roztoky     21.6  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.9  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.2  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.8  None        -   None  None      None    None   NaN
# ...          ...      ...   ...      ...    ...   ...       ...     ...   ...
# Roztoky  Roztoky     26.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     24.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.8  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.7  None        -   None  None      None    None   NaN
#
#                    datetime
# Stanica
# Roztoky 2025-07-30 14:00:00
# Roztoky 2025-07-30 15:00:00
# Roztoky 2025-07-30 16:00:00
# Roztoky 2025-07-30 17:00:00
# Roztoky 2025-07-30 18:00:00
# ...                     ...
# Roztoky 2025-08-16 19:00:00
# Roztoky 2025-08-16 20:00:00
# Roztoky 2025-08-16 21:00:00
# Roztoky 2025-08-16 22:00:00
# Roztoky 2025-08-16 23:00:00
#
# [418 rows x 10 columns]

# %%
tff.astype(pd.Float32Dtype()).info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 40651 entries, 84 to 95
# Series name: Teplota
# Non-Null Count  Dtype
# --------------  -----
# 40651 non-null  Float32
# dtypes: Float32(1)
# memory usage: 516.1 KB

# %%
import matplotlib.pyplot as plt
plt.hist(tf.Teplota, bins=50)
plt.xlabel('Teplota')
plt.ylabel('Frequency')
plt.title('Histogram of Teplota')
plt.show()

# %%
tf
# Out:
#          Stanica  Teplota  Smer Rýchlosť Nárazy  Tlak Oblačnosť Počasie  Graf  \
# Stanica
# Roztoky  Roztoky     21.6  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.9  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.2  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.8  None        -   None  None      None    None   NaN
# ...          ...      ...   ...      ...    ...   ...       ...     ...   ...
# Roztoky  Roztoky     26.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     24.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.8  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.7  None        -   None  None      None    None   NaN
#
#                    datetime
# Stanica
# Roztoky 2025-07-30 14:00:00
# Roztoky 2025-07-30 15:00:00
# Roztoky 2025-07-30 16:00:00
# Roztoky 2025-07-30 17:00:00
# Roztoky 2025-07-30 18:00:00
# ...                     ...
# Roztoky 2025-08-16 19:00:00
# Roztoky 2025-08-16 20:00:00
# Roztoky 2025-08-16 21:00:00
# Roztoky 2025-08-16 22:00:00
# Roztoky 2025-08-16 23:00:00
#
# [418 rows x 10 columns]

# %%
tf
# Out:
#          Stanica  Teplota  Smer Rýchlosť Nárazy  Tlak Oblačnosť Počasie  Graf  \
# Stanica
# Roztoky  Roztoky     21.6  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.9  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.2  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.8  None        -   None  None      None    None   NaN
# ...          ...      ...   ...      ...    ...   ...       ...     ...   ...
# Roztoky  Roztoky     26.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     24.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.8  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.7  None        -   None  None      None    None   NaN
#
#                    datetime
# Stanica
# Roztoky 2025-07-30 14:00:00
# Roztoky 2025-07-30 15:00:00
# Roztoky 2025-07-30 16:00:00
# Roztoky 2025-07-30 17:00:00
# Roztoky 2025-07-30 18:00:00
# ...                     ...
# Roztoky 2025-08-16 19:00:00
# Roztoky 2025-08-16 20:00:00
# Roztoky 2025-08-16 21:00:00
# Roztoky 2025-08-16 22:00:00
# Roztoky 2025-08-16 23:00:00
#
# [418 rows x 10 columns]

# %%
tf.columns
# Out:
# Index(['Stanica', 'Teplota', 'Smer', 'Rýchlosť', 'Nárazy', 'Tlak', 'Oblačnosť',
#        'Počasie', 'Graf', 'datetime'],
#       dtype='object')

# %%
tf['datetime']
# Out:
# Stanica
# Roztoky   2025-07-30 14:00:00
# Roztoky   2025-07-30 15:00:00
# Roztoky   2025-07-30 16:00:00
# Roztoky   2025-07-30 17:00:00
# Roztoky   2025-07-30 18:00:00
#                   ...
# Roztoky   2025-08-16 19:00:00
# Roztoky   2025-08-16 20:00:00
# Roztoky   2025-08-16 21:00:00
# Roztoky   2025-08-16 22:00:00
# Roztoky   2025-08-16 23:00:00
# Name: datetime, Length: 418, dtype: datetime64[us]

# %%
tf
# Out:
#          Stanica  Teplota  Smer Rýchlosť Nárazy  Tlak Oblačnosť Počasie  Graf  \
# Stanica
# Roztoky  Roztoky     21.6  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.9  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.2  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.8  None        -   None  None      None    None   NaN
# ...          ...      ...   ...      ...    ...   ...       ...     ...   ...
# Roztoky  Roztoky     26.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     24.4  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.8  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     22.5  None        -   None  None      None    None   NaN
# Roztoky  Roztoky     21.7  None        -   None  None      None    None   NaN
#
#                    datetime
# Stanica
# Roztoky 2025-07-30 14:00:00
# Roztoky 2025-07-30 15:00:00
# Roztoky 2025-07-30 16:00:00
# Roztoky 2025-07-30 17:00:00
# Roztoky 2025-07-30 18:00:00
# ...                     ...
# Roztoky 2025-08-16 19:00:00
# Roztoky 2025-08-16 20:00:00
# Roztoky 2025-08-16 21:00:00
# Roztoky 2025-08-16 22:00:00
# Roztoky 2025-08-16 23:00:00
#
# [418 rows x 10 columns]

# %%
tf.datetime
# Out:
# Stanica
# Roztoky   2025-07-30 14:00:00
# Roztoky   2025-07-30 15:00:00
# Roztoky   2025-07-30 16:00:00
# Roztoky   2025-07-30 17:00:00
# Roztoky   2025-07-30 18:00:00
#                   ...
# Roztoky   2025-08-16 19:00:00
# Roztoky   2025-08-16 20:00:00
# Roztoky   2025-08-16 21:00:00
# Roztoky   2025-08-16 22:00:00
# Roztoky   2025-08-16 23:00:00
# Name: datetime, Length: 418, dtype: datetime64[us]

# %%
tf['datetime']
# Out:
# Stanica
# Roztoky   2025-07-30 14:00:00
# Roztoky   2025-07-30 15:00:00
# Roztoky   2025-07-30 16:00:00
# Roztoky   2025-07-30 17:00:00
# Roztoky   2025-07-30 18:00:00
#                   ...
# Roztoky   2025-08-16 19:00:00
# Roztoky   2025-08-16 20:00:00
# Roztoky   2025-08-16 21:00:00
# Roztoky   2025-08-16 22:00:00
# Roztoky   2025-08-16 23:00:00
# Name: datetime, Length: 418, dtype: datetime64[us]

# %%
tf['datetime']
# Out:
# Stanica
# Roztoky   2025-07-30 14:00:00
# Roztoky   2025-07-30 15:00:00
# Roztoky   2025-07-30 16:00:00
# Roztoky   2025-07-30 17:00:00
# Roztoky   2025-07-30 18:00:00
#                   ...
# Roztoky   2025-08-16 19:00:00
# Roztoky   2025-08-16 20:00:00
# Roztoky   2025-08-16 21:00:00
# Roztoky   2025-08-16 22:00:00
# Roztoky   2025-08-16 23:00:00
# Name: datetime, Length: 418, dtype: datetime64[us]

# %%
tf[['datetime']]
# Out:
#                    datetime
# Stanica
# Roztoky 2025-07-30 14:00:00
# Roztoky 2025-07-30 15:00:00
# Roztoky 2025-07-30 16:00:00
# Roztoky 2025-07-30 17:00:00
# Roztoky 2025-07-30 18:00:00
# ...                     ...
# Roztoky 2025-08-16 19:00:00
# Roztoky 2025-08-16 20:00:00
# Roztoky 2025-08-16 21:00:00
# Roztoky 2025-08-16 22:00:00
# Roztoky 2025-08-16 23:00:00
#
# [418 rows x 1 columns]

# %%
dt = tf[['datetime', 'Teplota']]
print(dt.head())
dt.info()
dt['Teplota'].astype(float).describe()
# Out:
#                    datetime  Teplota
# Stanica
# Roztoky 2025-07-30 14:00:00     21.6
# Roztoky 2025-07-30 15:00:00     21.9
# Roztoky 2025-07-30 16:00:00     22.2
# Roztoky 2025-07-30 17:00:00     21.5
# Roztoky 2025-07-30 18:00:00     21.8
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, Roztoky to Roztoky
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  418 non-null    datetime64[us]
#  1   Teplota   418 non-null    float64
# dtypes: datetime64[us](1), float64(1)
# memory usage: 26.0+ KB
# count    418.000000
# mean      18.938995
# std        5.138260
# min        8.100000
# 25%       15.300000
# 50%       18.500000
# 75%       22.400000
# max       30.400000
# Name: Teplota, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
sns.boxplot(x=dt['Teplota'].astype(float))
plt.show()

# %%
sns.swarmplot(x=dt['Teplota'].astype(float).head(1000))
plt.show()

# %%
sns.set_theme(style="whitegrid")
ax = sns.x(data=dt.head(100).sort_values(by=['datetime']), x="datetime", y="Teplota")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.rcParams['figure.figsize'] = [10, 10]
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[181], line 2
#       1 sns.set_theme(style="whitegrid")
# ----> 2 ax = sns.x(data=dt.head(100).sort_values(by=['datetime']), x="datetime", y="Teplota")
#       3 ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
#       4 plt.rcParams['figure.figsize'] = [10, 10]
#
# AttributeError: module 'seaborn' has no attribute 'x'

# %%
data=dt.head(10000).sort_values(by=['datetime'])
data['Teplota'] = data['Teplota'].astype(float)
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, Roztoky to Roztoky
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  418 non-null    datetime64[us]
#  1   Teplota   418 non-null    float64
# dtypes: datetime64[us](1), float64(1)
# memory usage: 9.8+ KB
#                   datetime     Teplota
# count                  418  418.000000
# mean   2025-08-08 06:30:00   18.938995
# min    2025-07-30 14:00:00    8.100000
# 25%    2025-08-03 22:15:00   15.300000
# 50%    2025-08-08 06:30:00   18.500000
# 75%    2025-08-12 14:45:00   22.400000
# max    2025-08-16 23:00:00   30.400000
# std                    NaN    5.138260

# %%
df.Teplota = df.Teplota.astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40651 entries, Trenčín to Žiharec
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Stanica    40651 non-null  object
#  1   Teplota    40651 non-null  float64
#  2   Smer       40224 non-null  object
#  3   Rýchlosť   40651 non-null  object
#  4   Nárazy     379 non-null    object
#  5   Tlak       16339 non-null  object
#  6   Oblačnosť  6451 non-null   object
#  7   Počasie    516 non-null    object
#  8   Graf       0 non-null      float64
#  9   datetime   40651 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(2), object(7)
# memory usage: 4.4+ MB

# %%
df.index.unique()
# Out:
# Index(['Trenčín', 'Rožňava', 'Roztoky', 'Rimavská Sobota', 'Revúca', 'Ratková',
#        'Rabča', 'Prievidza', 'Prešov', 'Poprad',
#        ...
#        'Žilina - letisko', 'Žiharec', 'Žilina', 'Žilina - Dolný Hričov',
#        'Kojsovská hoľa', 'Štrbské pleso', 'Želiezovce', 'Donovaly',
#        'Košice - letisko', 'Lučenec - Boľkovce'],
#       dtype='object', name='Stanica', length=104)

# %%
data=df.loc[['Dudince', 'Žilina','Chopok'],['Teplota','datetime']]
data=df.loc[['Dudince', 'Chopok'],['Teplota','datetime']]

plt.figure(figsize=(25, 10))
plt.plot(data['datetime'], data['Teplota'],marker='o', linestyle='-')
plt.xlabel('Datetime')
plt.ylabel('Teplota')
plt.title('Teplota over Time')
plt.xticks(rotation=90)
plt.tight_layout()
plt.size=(150, 10)
plt.show()

# %%
plt.size
# Out:
# (150, 10)

# %%
dir(decimal)
# Out:
# ['BasicContext',
#  'Clamped',
#  'Context',
#  'ConversionSyntax',
#  'Decimal',
#  'DecimalException',
#  'DecimalTuple',
#  'DefaultContext',
#  'DivisionByZero',
#  'DivisionImpossible',
#  'DivisionUndefined',
#  'ExtendedContext',
#  'FloatOperation',
#  'HAVE_CONTEXTVAR',
#  'HAVE_THREADS',
#  'Inexact',
#  'InvalidContext',
#  'InvalidOperation',
#  'MAX_EMAX',
#  'MAX_PREC',
#  'MIN_EMIN',
#  'MIN_ETINY',
#  'Overflow',
#  'ROUND_05UP',
#  'ROUND_CEILING',
#  'ROUND_DOWN',
#  'ROUND_FLOOR',
#  'ROUND_HALF_DOWN',
#  'ROUND_HALF_EVEN',
#  'ROUND_HALF_UP',
#  'ROUND_UP',
#  'Rounded',
#  'Subnormal',
#  'Underflow',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__libmpdec_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  'getcontext',
#  'localcontext',
#  'setcontext']
