# %%
import pandas as pd
import numpy as np
import matplotlib as mp

TOPDIR = f'/home/pp/program/jupyter/Brezno - Klima/'
TEMPDIR= f'/home/pp/program/jupyter/Brezno - Klima/temp/'
UHRNDIR = f'/home/pp/program/jupyter/Brezno - Klima/uhrn/'
TEMPTESTFILE = TEMPDIR + '2025-07-30-15-00.html'
UHRNTESTFILE = UHRNDIR + '2025-07-30-23-45.html'
tables = pd.read_html(TEMPTESTFILE)

# %%
tables[0]
len(tables[0])
# Out:
# 97

# %%
dir(tables)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(tables[0])
print(type(tables))
print(type(tables[0]))
# Out:
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>

# %%
t=tables[0]
t
# Out:
#           Unnamed: 0_level_0 Unnamed: 1_level_0 Vietor                  \
#                      Stanica            Teplota   Smer Rýchlosť Nárazy
# 0   Banská Bystrica - Zelená            24.4 °C     SZ    2 m/s    NaN
# 1           Banská Štiavnica            22.6 °C      S    3 m/s    NaN
# 2                   Bardejov            21.7 °C      Z    1 m/s    NaN
# 3                     Beluša            23.8 °C     SZ    3 m/s    NaN
# 4                   Boľkovce            26.3 °C      J    2 m/s    NaN
# ..                       ...                ...    ...      ...    ...
# 92           Žiar nad Hronom            25.4 °C     SZ    2 m/s    NaN
# 93                   Žiharec            24.8 °C     SZ    3 m/s    NaN
# 94                    Žikava            24.6 °C      S    2 m/s    NaN
# 95                    Žilina            23.1 °C     JZ    2 m/s    NaN
# 96          Žilina - letisko            22.5 °C     JZ    3 m/s    NaN
#
#    Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0 Unnamed: 8_level_0
#                  Tlak          Oblačnosť            Počasie               Graf
# 0          1013.4 hPa                NaN                NaN                NaN
# 1          1013.0 hPa                NaN                NaN                NaN
# 2          1013.4 hPa                NaN                NaN                NaN
# 3          1014.8 hPa                NaN                NaN                NaN
# 4          1013.2 hPa     Malá oblačnosť                NaN                NaN
# ..                ...                ...                ...                ...
# 92         1013.8 hPa                NaN                NaN                NaN
# 93                NaN                NaN                NaN                NaN
# 94                NaN                NaN                NaN                NaN
# 95                NaN                NaN                NaN                NaN
# 96         1014.0 hPa            Oblačno                NaN                NaN
#
# [97 rows x 9 columns]

# %%
# t.columns = t.columns.droplevel(0)
t1 = t.loc[1:5]
# t1.droplevel(0)
t1.columns.levels[1]
t2 = t1
t2.columns = t2.columns.droplevel(0)
t2
# Out:
#                        Stanica  Teplota Smer Rýchlosť  Nárazy        Tlak  \
# 1             Banská Štiavnica  22.6 °C    S    3 m/s     NaN  1013.0 hPa
# 2                     Bardejov  21.7 °C    Z    1 m/s     NaN  1013.4 hPa
# 3                       Beluša  23.8 °C   SZ    3 m/s     NaN  1014.8 hPa
# 4                     Boľkovce  26.3 °C    J    2 m/s     NaN  1013.2 hPa
# 5  Bratislava - Mlynská Dolina  23.9 °C    S    2 m/s     NaN  1015.2 hPa
#
#         Oblačnosť Počasie  Graf
# 1             NaN     NaN   NaN
# 2             NaN     NaN   NaN
# 3             NaN     NaN   NaN
# 4  Malá oblačnosť     NaN   NaN
# 5             NaN     NaN   NaN

# %%
# print(t2.iloc[0:2, 0:2])
# print(t2.loc[:,:]) #OK
# print(t2.loc[0:2]) #OK
# print(t2.loc[0:2,:]) #OK
print(t2.iloc[0:2,0:3]) #OK
print(t2.loc[0:2,'Stanica':'Smer']) #OK
# Out:
#             Stanica  Teplota Smer
# 1  Banská Štiavnica  22.6 °C    S
# 2          Bardejov  21.7 °C    Z
#             Stanica  Teplota Smer
# 1  Banská Štiavnica  22.6 °C    S
# 2          Bardejov  21.7 °C    Z

# %%
t3 = t2
t3.index = t3.Stanica
print(t3['Bardejov':'Boľkovce'])
print(t3.loc['Bardejov':'Boľkovce'])
print(t3.loc[:, 'Smer':'Nárazy'])
print(t3.loc['Bardejov':'Boľkovce', 'Smer':'Rýchlosť'])
print(t3.loc['Boľkovce', 'Rýchlosť'])
# Out:
#            Stanica  Teplota Smer Rýchlosť  Nárazy        Tlak       Oblačnosť  \
# Stanica
# Bardejov  Bardejov  21.7 °C    Z    1 m/s     NaN  1013.4 hPa             NaN
# Beluša      Beluša  23.8 °C   SZ    3 m/s     NaN  1014.8 hPa             NaN
# Boľkovce  Boľkovce  26.3 °C    J    2 m/s     NaN  1013.2 hPa  Malá oblačnosť
#
#          Počasie  Graf
# Stanica
# Bardejov     NaN   NaN
# Beluša       NaN   NaN
# Boľkovce     NaN   NaN
#            Stanica  Teplota Smer Rýchlosť  Nárazy        Tlak       Oblačnosť  \
# Stanica
# Bardejov  Bardejov  21.7 °C    Z    1 m/s     NaN  1013.4 hPa             NaN
# Beluša      Beluša  23.8 °C   SZ    3 m/s     NaN  1014.8 hPa             NaN
# Boľkovce  Boľkovce  26.3 °C    J    2 m/s     NaN  1013.2 hPa  Malá oblačnosť
#
#          Počasie  Graf
# Stanica
# Bardejov     NaN   NaN
# Beluša       NaN   NaN
# Boľkovce     NaN   NaN
#                             Smer Rýchlosť  Nárazy
# Stanica
# Banská Štiavnica               S    3 m/s     NaN
# Bardejov                       Z    1 m/s     NaN
# Beluša                        SZ    3 m/s     NaN
# Boľkovce                       J    2 m/s     NaN
# Bratislava - Mlynská Dolina    S    2 m/s     NaN
#          Smer Rýchlosť
# Stanica
# Bardejov    Z    1 m/s
# Beluša     SZ    3 m/s
# Boľkovce    J    2 m/s
# 2 m/s

# %%
t3[t3['Rýchlosť'] < '2']
t3.Stanica > 'Be'
t3[t3.Stanica < 'Be']
t3[t3.Stanica < 'Be']
t4 =t3
t4.index[2]
t4.iloc[2]
t4.loc['Beluša']
# Out:
# Stanica          Beluša
# Teplota         23.8 °C
# Smer                 SZ
# Rýchlosť          3 m/s
# Nárazy              NaN
# Tlak         1014.8 hPa
# Oblačnosť           NaN
# Počasie             NaN
# Graf                NaN
# Name: Beluša, dtype: object
