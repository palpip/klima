# %%
import pandas as pd
import numpy as np
import re
import openpyxl
import datetime
import sqlite3
import pyarrow as pa
import pyarrow.parquet as pq
from pathlib import Path
import decimal
import csv
TOPDIR = r'/home/pp/program/jupyter/Brezno - Klima/'
TEMPDIR= TOPDIR + r'temp/'

# Replace 'your_file.parquet' with the path to your Parquet file
# df = pd.read_parquet(TEMPDIR + 'teplotyx.parquet', engine='pyarrow')  
df = pd.read_parquet(TEMPDIR + 'teplotyx.parquet', engine='auto')
d0 = df.copy()
df = df.replace({'Rýchlosť':'-'}, None)
df = df.astype({'Teplota': pd.Float64Dtype(), 'Rýchlosť': pd.Float64Dtype(),'Tlak': pd.Float64Dtype()}, copy=False)
# df.info()
# print(df['Rýchlosť'] == '-')

ndx = pd.isnull(df['Rýchlosť'])
print(ndx)
print(df.loc[ndx,:])
df                       
# df = df[df['Rýchlosť'] == '-']
# df
# Out:
# 50    False
# 67    False
# 66    False
# 65    False
# 64     True
#       ...
# 25    False
# 26    False
# 27    False
# 13    False
# 95    False
# Name: Rýchlosť, Length: 59420, dtype: bool
#              Stanica  Teplota  Smer  Rýchlosť Nárazy    Tlak     Oblačnosť  \
# 64           Roztoky     21.6  None      <NA>   None    <NA>          None
# 64           Roztoky     21.9  None      <NA>   None    <NA>          None
# 64           Roztoky     22.2  None      <NA>   None    <NA>          None
# 64           Roztoky     21.5  None      <NA>   None    <NA>          None
# 64           Roztoky     21.8  None      <NA>   None    <NA>          None
# ..               ...      ...   ...       ...    ...     ...           ...
# 65           Roztoky     10.0  None      <NA>   None    <NA>          None
# 64           Roztoky     10.6  None      <NA>   None    <NA>          None
# 97  Žilina - letisko     11.4  PREM      <NA>   None  1019.4  Takmer jasno
# 98  Žilina - letisko      9.2  PREM      <NA>   None  1020.1  Takmer jasno
# 65           Roztoky      7.7  None      <NA>   None    <NA>          None
#
#    Počasie  Graf            datetime
# 64    None   NaN 2025-07-30 14:00:00
# 64    None   NaN 2025-07-30 15:00:00
# 64    None   NaN 2025-07-30 16:00:00
# 64    None   NaN 2025-07-30 17:00:00
# 64    None   NaN 2025-07-30 18:00:00
# ..     ...   ...                 ...
# 65    None   NaN 2025-08-24 20:00:00
# 64    None   NaN 2025-08-24 21:00:00
# 97    None   NaN 2025-08-24 21:00:00
# 98    None   NaN 2025-08-24 22:00:00
# 65    None   NaN 2025-08-24 22:00:00
#
# [696 rows x 10 columns]
#                 Stanica  Teplota  Smer  Rýchlosť Nárazy    Tlak  \
# 50     Oravský Podzámok     21.3     S       1.0   None    <NA>
# 67               Senica     23.4    SZ       2.0   None  1015.1
# 66           Ružomberok     22.8    JZ       3.0   None    <NA>
# 65              Rožňava     24.5    JV       1.0   None  1013.2
# 64              Roztoky     21.6  None      <NA>   None    <NA>
# ..                  ...      ...   ...       ...    ...     ...
# 25       Kojšovská hoľa      7.1    SV       2.0   None    <NA>
# 26               Košice     13.7  PREM       1.0   None  1018.8
# 27  Košice - Podhradová     11.6     Z       2.0   None  1019.0
# 13      Červený Kláštor      5.7     J       2.0   None  1021.6
# 95              Žiharec     11.1     J       1.0   None    <NA>
#
#          Oblačnosť Počasie  Graf            datetime
# 50            None    None   NaN 2025-07-30 14:00:00
# 67            None    None   NaN 2025-07-30 14:00:00
# 66            None    None   NaN 2025-07-30 14:00:00
# 65            None    None   NaN 2025-07-30 14:00:00
# 64            None    None   NaN 2025-07-30 14:00:00
# ..             ...     ...   ...                 ...
# 25            None    None   NaN 2025-08-24 22:00:00
# 26  Malá oblačnosť    None   NaN 2025-08-24 22:00:00
# 27            None    None   NaN 2025-08-24 22:00:00
# 13            None    None   NaN 2025-08-24 22:00:00
# 95            None    None   NaN 2025-08-24 22:00:00
#
# [59420 rows x 10 columns]

# %%
d0 = df
# tl = df['Rýchlosť'].astype(pd.Float64Dtype())
# d1 = df[df['Rýchlosť'] == None]
# d1
# df[df['Rýchlosť'] == '-'] = np.nan
# df[df['Rýchlosť'] == np.nan] = 0
# df[df['Rýchlosť'].isna()] = 0


# df.info()
# df
d0
# Out:
#                 Stanica  Teplota  Smer  Rýchlosť Nárazy    Tlak  \
# 50     Oravský Podzámok     21.3     S       1.0   None    <NA>
# 67               Senica     23.4    SZ       2.0   None  1015.1
# 66           Ružomberok     22.8    JZ       3.0   None    <NA>
# 65              Rožňava     24.5    JV       1.0   None  1013.2
# 64              Roztoky     21.6  None      <NA>   None    <NA>
# ..                  ...      ...   ...       ...    ...     ...
# 25       Kojšovská hoľa      7.1    SV       2.0   None    <NA>
# 26               Košice     13.7  PREM       1.0   None  1018.8
# 27  Košice - Podhradová     11.6     Z       2.0   None  1019.0
# 13      Červený Kláštor      5.7     J       2.0   None  1021.6
# 95              Žiharec     11.1     J       1.0   None    <NA>
#
#          Oblačnosť Počasie  Graf            datetime
# 50            None    None   NaN 2025-07-30 14:00:00
# 67            None    None   NaN 2025-07-30 14:00:00
# 66            None    None   NaN 2025-07-30 14:00:00
# 65            None    None   NaN 2025-07-30 14:00:00
# 64            None    None   NaN 2025-07-30 14:00:00
# ..             ...     ...   ...                 ...
# 25            None    None   NaN 2025-08-24 22:00:00
# 26  Malá oblačnosť    None   NaN 2025-08-24 22:00:00
# 27            None    None   NaN 2025-08-24 22:00:00
# 13            None    None   NaN 2025-08-24 22:00:00
# 95            None    None   NaN 2025-08-24 22:00:00
#
# [59420 rows x 10 columns]
